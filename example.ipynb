# %%
from benchmark.benchmark import Benchmark
from random import randrange
import importlib
import builtins
import time

def randlist(count, min=0, max=100):
    return [randrange(min, max) for _ in range(2*count)]


def my_sorted(x):
#     time.sleep(1)
    return sorted(x)

# %%
from benchmark.benchmark import Benchmark

benchmark = Benchmark(randlist, my_sorted)

# %%
benchmark.make_random_measurements()
# Out:
# [(2, 2.695014700293541e-06),
#  (2, 1.1289957910776138e-06),
#  (2, 9.530049283057451e-07),
#  (3, 1.186999725177884e-06),
#  (3, 1.0799849405884743e-06),
#  (4, 1.4370016288012266e-06),
#  (4, 4.951987648382783e-06),
#  (5, 6.064015906304121e-06),
#  (5, 5.3480034694075584e-06),
#  (5, 5.69300027564168e-06),
#  (5, 5.542009603232145e-06),
#  (5, 5.346984835341573e-06),
#  (6, 6.799993570894003e-06),
#  (6, 7.56300869397819e-06),
#  (6, 6.510003004223108e-06),
#  (7, 7.010996341705322e-06),
#  (7, 7.551978342235088e-06),
#  (7, 7.287017069756985e-06),
#  (8, 7.943017408251762e-06),
#  (8, 8.042989065870643e-06),
#  (8, 7.974012987688184e-06),
#  (9, 9.491021046414971e-06),
#  (9, 1.0122981620952487e-05),
#  (9, 9.276001947000623e-06),
#  (9, 8.705974323675036e-06),
#  (9, 8.189002983272076e-06),
#  (10, 9.41200414672494e-06),
#  (10, 9.53700509853661e-06),
#  (12, 2.9600050766021013e-06),
#  (12, 2.7370115276426077e-06),
#  (12, 2.816988853737712e-06),
# ...

# %%
benchmark.predict_complexity()
# Out:
# predict_complexity_('my_sorted',) = O( n )
# 'O( n )'

# %%
benchmark.plot_measurements()

# %%
benchmark.time_for_size(3000)
# Out:
# time_for_size_(3000,) = 0.00158378411861
# 0.0015837841186117604

# %%
benchmark.size_for_time(20)
# Out:
# size_for_time_(20,) = 37883951.5
# 37883951.5

# %%
benchmark.time_for_size(37883951)
# Out:
# time_for_size_(37883951,) = 19.9999999814
# 19.999999981355373

# %%
print(benchmark.predicted_complexity_name)
print(benchmark.predicted_complexity_certainty)
print(benchmark.predicted_complexity_const)
# Out:
# n
# 0.302657787292
# 5.27928039537e-07
